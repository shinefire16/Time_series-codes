# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0,8.0)
# Out:
# C:\Users\GURU\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv("C:/Users/GURU/Desktop/1_week/darksky_historical.csv",sep=";")

# %%
df.head()
# Out:
#    plant_id         datetime_utc       datetime_local  cloud_cover  \
# 0        13  2010-12-31 18:30:00  2011-01-01 00:00:00         0.30
# 1        13  2010-12-31 19:30:00  2011-01-01 01:00:00         0.31
# 2        13  2010-12-31 20:30:00  2011-01-01 02:00:00         0.31
# 3        13  2010-12-31 21:30:00  2011-01-01 03:00:00         0.10
# 4        13  2010-12-31 22:30:00  2011-01-01 04:00:00         0.31
#
#    apparent_temperature  temperature  humidity  dew_point  wind_bearing  \
# 0                  8.44         9.68      0.95       8.95         230.0
# 1                  7.71         8.89      1.00       8.89         240.0
# 2                  7.71         8.89      1.00       8.89         250.0
# 3                  7.76         8.90      0.95       8.20         273.0
# 4                  8.44        10.00      1.00      10.00         270.0
#
#    wind_speed         ...           precip_accumulation  precip_intensity  \
# ...

# %%
df.tail()
# Out:
#        plant_id         datetime_utc       datetime_local  cloud_cover  \
# 69551        13  2018-12-09 13:30:00  2018-12-09 19:00:00          0.0
# 69552        13  2018-12-09 14:30:00  2018-12-09 20:00:00          0.0
# 69553        13  2018-12-09 15:30:00  2018-12-09 21:00:00          0.0
# 69554        13  2018-12-09 16:30:00  2018-12-09 22:00:00          0.0
# 69555        13  2018-12-09 17:30:00  2018-12-09 23:00:00          0.0
#
#        apparent_temperature  temperature  humidity  dew_point  wind_bearing  \
# 69551                 17.48        17.48      0.72      12.28           NaN
# 69552                 15.51        15.51      0.68       9.64           NaN
# 69553                 14.01        14.01      0.65       7.50          36.0
# 69554                 13.51        13.51      0.69       8.01          55.0
# 69555                 12.74        12.74      0.71       7.52          73.0
#
#        wind_speed         ...           precip_accumulation  precip_intensity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69556 entries, 0 to 69555
# Data columns (total 30 columns):
# plant_id                69556 non-null int64
# datetime_utc            69556 non-null object
# datetime_local          69556 non-null object
# cloud_cover             52882 non-null float64
# apparent_temperature    69276 non-null float64
# temperature             69276 non-null float64
# humidity                69267 non-null float64
# dew_point               69267 non-null float64
# wind_bearing            58830 non-null float64
# wind_speed              61032 non-null float64
# wind_chill              0 non-null float64
# wind_gust               6103 non-null float64
# heat_index              0 non-null float64
# pressure                27874 non-null float64
# qpf                     0 non-null float64
# uv_index                6112 non-null float64
# snow                    0 non-null float64
# pop                     0 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# plant_id                    0
# datetime_utc                0
# datetime_local              0
# cloud_cover             16674
# apparent_temperature      280
# temperature               280
# humidity                  289
# dew_point                 289
# wind_bearing            10726
# wind_speed               8524
# wind_chill              69556
# wind_gust               63453
# heat_index              69556
# pressure                41682
# qpf                     69556
# uv_index                63444
# snow                    69556
# pop                     69556
# fctcode                 69556
# ozone                   63436
# precip_accumulation     69556
# precip_intensity        63436
# precip_probability      63436
# precip_type              4543
# visibility                181
# sunrise                     0
# sunset                      0
# icon                        0
# summary                     0
# updated_at                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['plant_id', 'datetime_utc', 'datetime_local', 'cloud_cover',
#        'apparent_temperature', 'temperature', 'humidity', 'dew_point',
#        'wind_bearing', 'wind_speed', 'wind_chill', 'wind_gust', 'heat_index',
#        'pressure', 'qpf', 'uv_index', 'snow', 'pop', 'fctcode', 'ozone',
#        'precip_accumulation', 'precip_intensity', 'precip_probability',
#        'precip_type', 'visibility', 'sunrise', 'sunset', 'icon', 'summary',
#        'updated_at'],
#       dtype='object')

# %% [markdown]
# As we can see['wind_chill', 'wind_gust', 'heat_index',
#        'pressure', 'qpf', 'uv_index', 'snow', 'pop', 'fctcode', 'ozone',
#        'precip_accumulation', 'precip_intensity', 'precip_probability',] these variable contains lots of null values and Missing values

# %%
df.drop(['wind_chill', 'wind_gust', 'heat_index',
       'pressure', 'qpf', 'uv_index', 'snow', 'pop','fctcode','ozone',
       'precip_accumulation', 'precip_intensity','precip_probability'],axis = 1,inplace = True)

# %%
df2=df.copy()

# %%
df2.head(50)
# Out:
#     plant_id         datetime_utc       datetime_local  cloud_cover  \
# 0         13  2010-12-31 18:30:00  2011-01-01 00:00:00         0.30
# 1         13  2010-12-31 19:30:00  2011-01-01 01:00:00         0.31
# 2         13  2010-12-31 20:30:00  2011-01-01 02:00:00         0.31
# 3         13  2010-12-31 21:30:00  2011-01-01 03:00:00         0.10
# 4         13  2010-12-31 22:30:00  2011-01-01 04:00:00         0.31
# 5         13  2010-12-31 23:30:00  2011-01-01 05:00:00         0.75
# 6         13  2011-01-01 00:30:00  2011-01-01 06:00:00         0.69
# 7         13  2011-01-01 01:30:00  2011-01-01 07:00:00         0.31
# 8         13  2011-01-01 02:30:00  2011-01-01 08:00:00         0.31
# 9         13  2011-01-01 03:30:00  2011-01-01 09:00:00         0.00
# 10        13  2011-01-01 04:30:00  2011-01-01 10:00:00         0.15
# 11        13  2011-01-01 05:30:00  2011-01-01 11:00:00         0.31
# 12        13  2011-01-01 06:30:00  2011-01-01 12:00:00         0.10
# ...

# %%
df2.tail()
# Out:
#        plant_id         datetime_utc       datetime_local  cloud_cover  \
# 69551        13  2018-12-09 13:30:00  2018-12-09 19:00:00          0.0
# 69552        13  2018-12-09 14:30:00  2018-12-09 20:00:00          0.0
# 69553        13  2018-12-09 15:30:00  2018-12-09 21:00:00          0.0
# 69554        13  2018-12-09 16:30:00  2018-12-09 22:00:00          0.0
# 69555        13  2018-12-09 17:30:00  2018-12-09 23:00:00          0.0
#
#        apparent_temperature  temperature  humidity  dew_point  wind_bearing  \
# 69551                 17.48        17.48      0.72      12.28           NaN
# 69552                 15.51        15.51      0.68       9.64           NaN
# 69553                 14.01        14.01      0.65       7.50          36.0
# 69554                 13.51        13.51      0.69       8.01          55.0
# 69555                 12.74        12.74      0.71       7.52          73.0
#
#        wind_speed precip_type  visibility              sunrise  \
# ...

# %%
#missing Value by percentages

miss = df2.isnull().sum()/len(df2)
miss = miss[miss >0]
miss.sort_values(inplace = True)
miss
#miss = miss[miss > 0]
# Out:
# visibility              0.002602
# apparent_temperature    0.004026
# temperature             0.004026
# humidity                0.004155
# dew_point               0.004155
# precip_type             0.065314
# wind_speed              0.122549
# wind_bearing            0.154207
# cloud_cover             0.239721
# dtype: float64

# %%
df2.drop(['plant_id'],axis = 1,inplace = True)

# %%
df2.head()
# Out:
#           datetime_utc       datetime_local  cloud_cover  \
# 0  2010-12-31 18:30:00  2011-01-01 00:00:00         0.30
# 1  2010-12-31 19:30:00  2011-01-01 01:00:00         0.31
# 2  2010-12-31 20:30:00  2011-01-01 02:00:00         0.31
# 3  2010-12-31 21:30:00  2011-01-01 03:00:00         0.10
# 4  2010-12-31 22:30:00  2011-01-01 04:00:00         0.31
#
#    apparent_temperature  temperature  humidity  dew_point  wind_bearing  \
# 0                  8.44         9.68      0.95       8.95         230.0
# 1                  7.71         8.89      1.00       8.89         240.0
# 2                  7.71         8.89      1.00       8.89         250.0
# 3                  7.76         8.90      0.95       8.20         273.0
# 4                  8.44        10.00      1.00      10.00         270.0
#
#    wind_speed precip_type  visibility              sunrise  \
# 0        2.51        rain        0.82  2011-01-01 01:44:45
# 1        2.24        rain        0.48  2011-01-01 01:44:45
# ...

# %% [markdown]
# Replacing NaN values in wind_bearing variables
# and missing values before and after

# %%
miss_bool = df2['wind_bearing'].isnull() 

print ('Orignal #missing: %d'% sum(miss_bool))
df2['wind_bearing'].fillna((df2['wind_bearing'].mean()), inplace=True)
print ('Final #missing: %d'% sum(df2['wind_bearing'].isnull()))
# Out:
# Orignal #missing: 10726
# Final #missing: 0

# %%
df2.tail()
# Out:
#               datetime_utc       datetime_local  cloud_cover  \
# 69551  2018-12-09 13:30:00  2018-12-09 19:00:00          0.0
# 69552  2018-12-09 14:30:00  2018-12-09 20:00:00          0.0
# 69553  2018-12-09 15:30:00  2018-12-09 21:00:00          0.0
# 69554  2018-12-09 16:30:00  2018-12-09 22:00:00          0.0
# 69555  2018-12-09 17:30:00  2018-12-09 23:00:00          0.0
#
#        apparent_temperature  temperature  humidity  dew_point  wind_bearing  \
# 69551                 17.48        17.48      0.72      12.28    206.465596
# 69552                 15.51        15.51      0.68       9.64    206.465596
# 69553                 14.01        14.01      0.65       7.50     36.000000
# 69554                 13.51        13.51      0.69       8.01     55.000000
# 69555                 12.74        12.74      0.71       7.52     73.000000
#
#        wind_speed precip_type  visibility              sunrise  \
# 69551        0.00         NaN        2.24  2018-12-09 01:33:25
# ...

# %% [markdown]
# Variable 'temperature' and 'apparent_temperature' are highly correlated, so lets drop 'apparent_temperature' Variable

# %%
del df2['apparent_temperature']

# %%
df3 = df2.copy()

# %%
df3.tail()
# Out:
#               datetime_utc       datetime_local  cloud_cover  temperature  \
# 69551  2018-12-09 13:30:00  2018-12-09 19:00:00          0.0        17.48
# 69552  2018-12-09 14:30:00  2018-12-09 20:00:00          0.0        15.51
# 69553  2018-12-09 15:30:00  2018-12-09 21:00:00          0.0        14.01
# 69554  2018-12-09 16:30:00  2018-12-09 22:00:00          0.0        13.51
# 69555  2018-12-09 17:30:00  2018-12-09 23:00:00          0.0        12.74
#
#        humidity  dew_point  wind_bearing  wind_speed precip_type  visibility  \
# 69551      0.72      12.28    206.465596        0.00         NaN        2.24
# 69552      0.68       9.64    206.465596        0.00         NaN        2.27
# 69553      0.65       7.50     36.000000        0.88         NaN       13.20
# 69554      0.69       8.01     55.000000        1.84         NaN       13.10
# 69555      0.71       7.52     73.000000        2.04         NaN        3.81
#
# ...
